# %% [markdown]
# ## **Step 1: Problem Framing**

# %% [markdown]
# ### Objective
#
# To analyze the factors influencing startup growth and success in India using real-world funding data. The goal is to identify what drives a startup’s success — such as location, sector, or funding patterns — and uncover actionable insights for new founders and investors.
#
# ---
#
# ### Defining “Startup Success”
#
# In this project, we’ll define **startup success** based on **funding performance**, since our dataset primarily contains funding-related attributes.
#
# > **Definition:**
# > A startup is considered **successful** if it has raised **more than ₹10 Crores (~USD 1.2 Million)** in total funding.
#
# This definition is chosen because:
#
# * Funding represents external investor confidence and growth potential.
# * The dataset lacks variables like employee count or survival years.
# * It’s measurable and aligns with typical early-stage success indicators.
#
# We will convert `AmountInUSD` to INR (₹) for consistency and classify startups as:
#
# * **Successful:** Total funding > ₹10 Cr
# * **Not yet successful:** Total funding ≤ ₹10 Cr
#
# ---
#
# ### Hypotheses to Test
#
# We’ll test the following **3 hypotheses**:
#
# 1. **H1: Startups in Tier-1 cities (like Bengaluru, Mumbai, and Delhi NCR) raise higher average funding than those in Tier-2/3 cities.**
#    *Rationale:* Tier-1 cities have stronger investor ecosystems, accelerators, and tech hubs.
#
# 2. **H2: Startups in the FinTech and E-Commerce sectors attract more funding compared to other sectors.**
#    *Rationale:* These industries have shown rapid growth and investor interest in India.
#
# 3. **H3: The number of funding rounds is positively correlated with the total amount raised.**
#    *Rationale:* Startups that receive multiple rounds usually demonstrate growth and investor trust.
#
# ---
#
# ### Expected Outcome
#
# We expect to find:
#
# * Tier-1 city startups dominating funding totals.
# * FinTech and E-Commerce sectors leading in capital raised.
# * A clear positive correlation between number of rounds and total funding.
#
# ---

# %% [markdown]
# ## **Step 2: Data Cleaning & Preparation**

# %%
# Dataset import and explore
import pandas as pd

# When loading your data
df = pd.read_csv('startup_funding.csv', encoding='utf-8', engine='python', on_bad_lines='skip')

# Force all string columns to be treated as proper text
df = df.applymap(lambda x: x.encode('unicode_escape').decode('utf-8') if isinstance(x, str) else x)

print(df.head())
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                   BYJU\u2019S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# 1  Susquehanna Growth Equity              Series C     80,48,394     NaN
# 2      Sequoia Capital India              Series B   1,83,58,860     NaN
# 3             Vinod Khatumal          Pre-series A     30,00,000     NaN
# 4    Sprout Venture Partners            Seed Round     18,00,000     NaN
# /tmp/ipython-input-1012842769.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.encode('unicode_escape').decode('utf-8') if isinstance(x, str) else x)

# %%
# Data types of columns
df.dtypes
# Out:
# Sr No                 int64
# Date dd/mm/yyyy      object
# Startup Name         object
# Industry Vertical    object
# SubVertical          object
# City  Location       object
# Investors Name       object
# InvestmentnType      object
# Amount in USD        object
# Remarks              object
# dtype: object

# %%
# Getting familiar with the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
# Summary statistics before cleaning
df.describe()
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %%
# Checking for missing values in every column
df.isna().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
# Checking duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# As we are focusing on Funds and companies. We will remove NA values where company name or Amount is not available
df.dropna(subset = ['Startup Name','Amount in USD'],inplace=True)
df.shape
# Out:
# (2084, 10)

# %%
import numpy as np

# Column renaming and data type conversions
df = df.rename(columns={'Date dd/mm/yyyy':'Date','InvestmentnType':'Investment Type'})
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')
df['Date'] = df['Date'].fillna(method = 'bfill')

df['Amount in USD'] = (
    df['Amount in USD']
    .apply(lambda x: ''.join(ch for ch in str(x) if ch.isdigit() or ch == '.'))
    .replace('', np.nan)
    .astype(float)
)
# Out:
# /tmp/ipython-input-3573413364.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Date'] = df['Date'].fillna(method = 'bfill')

# %%
# As we are focusing on Funds and companies. We will remove NA values where company name or Amount is not available after processing
df.dropna(subset = ['Startup Name','Amount in USD'],inplace=True)
df.shape
# Out:
# (2077, 10)

# %%
df['Amount in USD'] = (df['Amount in USD']/(10**3)).round(2)# Converting the amount in millions for creating less range

# Current value of USD in INR
df.insert(loc=9, column='Amount in INR', value=(df['Amount in USD'] * 88).round(2))

# %%
df = df.rename(columns={'City  Location': 'City Location'})# there was two ' ' in the name

# Filling missing values of categorical columns
missing_values_columns = ['Industry Vertical','SubVertical','City Location','Investors Name','Investment Type']
df[missing_values_columns] = df[missing_values_columns].fillna('Unknown')
df['Remarks'] = df['Remarks'].fillna('No Remark')

# %%
# Amount in thousand(K)
df.rename(columns = {'Amount in USD':'Amount in USD(K)','Amount in INR':'Amount in INR(K)'},inplace= True)

# %%
# Rechecking data type conversion
df.dtypes
# Out:
# Sr No                         int64
# Date                 datetime64[ns]
# Startup Name                 object
# Industry Vertical            object
# SubVertical                  object
# City Location                object
# Investors Name               object
# Investment Type              object
# Amount in USD(K)            float64
# Amount in INR(K)            float64
# Remarks                      object
# dtype: object

# %%
# Number of unique values before cleaning
df['City Location'].nunique()
# Out:
# 92

# %%
# Clean 'City Location' thoroughly
df['City Location'] = (
    df['City Location']
    .astype(str)
    # Remove real non-breaking spaces and invisible Unicode
    .str.replace(u'\xa0', '', regex=False)
    # Remove encoded versions (\xc2\xa0 or Xc2Xa0)
    .str.replace(r'\\xc2|\\xa0|xc2xa0|Xc2Xa0|Xcxa', '', regex=True)
    # Remove unnecessary special characters
    .str.replace(r'[^\w\s,/&-]', '', regex=True)
    .str.strip()
)

# If multiple locations exist, keep only the first
df['City Location'] = df['City Location'].str.split('/|,|&|and').str[0].str.strip()

# Standardize common variants
df['City Location'] = df['City Location'].replace({
    'Bangalore': 'Bengaluru',
    'bangalore': 'Bengaluru',
    'Delhi': 'New Delhi',
    'new Delhi': 'New Delhi',
    'Gurugram': 'Gurgaon',
    'gurgaon': 'Gurgaon',
    'Bombay': 'Mumbai',
    'mumbai': 'Mumbai',
    'Bhubneswar': 'Bhubaneswar',
    'Triv': 'Trivandrum',
    'Ch': 'Chennai',
    'Sfo': 'San Francisco',
    'Us': 'USA',
    'Usa': 'USA',
    'Ahemadabad': 'Ahmedabad'
})

# Apply consistent capitalization
df['City Location'] = df['City Location'].str.title()

# Replace any leftover blanks or unknowns
df['City Location'] = df['City Location'].replace('', 'Unknown')

# Verify result
print(f"Number of unique values after cleaning: {df['City Location'].nunique()}\n")
print("Unique values:\n", df['City Location'].unique())
# Out:
# Number of unique values after cleaning: 57
#
# Unique values:
#  ['Bengaluru' 'Gurgaon' 'New Delhi' 'Mumbai' 'Chennai' 'Pune' 'Noida'
#  'Faridabad' 'San Francisco' 'San Jose' 'Amritsar' 'Kormangala' 'Tulangan'
#  'Hyderabad' 'Burnsville' 'Menlo Park' 'Palo Alto' 'Santa Monica'
#  'Singapore' 'Taramani' 'Andheri' 'Chembur' 'Nairobi' 'Haryana' 'New York'
#  'Karnataka' 'Bhopal' 'India' 'Jaipur' 'Nagpur' 'Indore' 'California'
#  'Ahmedabad' 'Rourkela' 'Bhubaneswar' 'Kolkata' 'Coimbatore' 'Udaipur'
#  'Surat' 'Goa' 'Gaya' 'Vadodara' 'Missourie' 'Panaji' 'Gwalior' 'Kerala'
#  'Unknown' 'Lucknow' 'Trivandrum' 'Varanasi' 'Kanpur' 'Jodhpur' 'Boston'
#  'Usa' 'Belgaum' 'Dallas' 'Udupi']

# %%
# Define city tiers
tier_1_india = ['Bengaluru', 'Mumbai', 'New Delhi', 'Chennai', 'Pune', 'Hyderabad', 'Gurgaon', 'Noida', 'Faridabad']
tier_1_international = ['San Francisco', 'New York', 'Singapore', 'San Jose', 'Menlo Park', 'Santa Monica', 'Boston', 'Dallas', 'Burnsville', 'Palo Alto']
# Tier 2/3 Indian cities (all remaining Indian cities except unknown)
tier_2_3_india = [
    'Jaipur', 'Lucknow', 'Coimbatore', 'Indore', 'Ahmedabad', 'Bhopal', 'Nagpur', 'Udaipur',
    'Surat', 'Goa', 'Gaya', 'Vadodara', 'Panaji', 'Gwalior', 'Belgaum', 'Udupi', 'Bhubneswar',
    'Kolkata', 'Amritsar', 'Triv', 'Kormangala', 'Tulangan', 'Taramani', 'Andheri', 'Chembur'
]

# Function to assign tier
def assign_tier(city):
    if city in tier_1_india:
        return 'Tier 1 India'
    elif city in tier_1_international:
        return 'Tier 1 International'
    elif city in tier_2_3_india:
        return 'Tier 2/3 India'
    else:
        return 'Other'

# Assign city a tier in new column
df['City Tier'] = df['City Location'].apply(assign_tier)

df[['City Location', 'City Tier']].head(10)
# Out:
#   City Location     City Tier
# 0     Bengaluru  Tier 1 India
# 1       Gurgaon  Tier 1 India
# 2     Bengaluru  Tier 1 India
# 3     New Delhi  Tier 1 India
# 4        Mumbai  Tier 1 India
# 5       Chennai  Tier 1 India
# 6       Gurgaon  Tier 1 India
# 7          Pune  Tier 1 India
# 8       Gurgaon  Tier 1 India
# 9     Bengaluru  Tier 1 India

# %%
# Number of unique values before cleaning
df['Industry Vertical'].nunique()
# Out:
# 595

# %%
# Clean and standardize 'Industry Vertical' column
col = 'Industry Vertical'

# Convert to string and remove encoded artifacts
df[col] = df[col].astype(str).str.replace(r'\\xc2|\\xa0|\\\\n', '', regex=True).str.strip()

# Fix casing inconsistencies
df[col] = df[col].str.title().str.strip()

# Remove unwanted symbols and extra spaces
df[col] = df[col].str.replace(r'[^\w\s&/-]', '', regex=True)

# Standardize common variants and misspellings
df[col] = df[col].replace({
    'Ecommece': 'E-Commerce',
    'Ecommerce': 'E-Commerce',
    'E-Commerce Platform': 'E-Commerce',
    'Ecommerce Platform': 'E-Commerce',
    'Ecommerce Marketplace': 'E-Commerce',
    'Ecomm': 'E-Commerce',
    'E Tech': 'E-Tech',
    'Fintech': 'FinTech',
    'Fin-Tech': 'FinTech',
    'Financial Tech': 'FinTech',
    'Financial Technology': 'FinTech',
    'Nbfc': 'NBFC',
    'Fiinance': 'Finance',
    'Health And Wellness': 'Health & Wellness',
    'Healthcare': 'Health & Wellness',
    'Health Care': 'Health & Wellness',
    'Edtech': 'EdTech',
    'Ed-Tech': 'EdTech',
    'Education': 'EdTech',
    'E Tech': 'EdTech',
    'Saas': 'SaaS',
    'Saas Platform': 'SaaS',
    'Tech': 'Technology',
    'It': 'Technology',
    'Artificial Intelligence Platform': 'Artificial Intelligence',
    'Clean-Tech': 'CleanTech',
    'Agtech': 'AgriTech',
    'Reality': 'Real Estate'
})

# Simplify long descriptive phrases into main industry categories
df[col] = df[col].replace({
    r'.*Food.*Delivery.*': 'Food Delivery',
    r'.*Grocery.*Delivery.*': 'Grocery Delivery',
    r'.*Food.*Tech.*': 'Food Tech',
    r'.*Food[- ]?And[- ]?Beverages.*': 'Food & Beverages',
    r'.*E-Learning.*': 'EdTech',
    r'.*Online.*Education.*': 'EdTech',
    r'.*Education.*Platform.*': 'EdTech',
    r'.*Online.*Marketplace.*': 'E-Commerce',
    r'.*E-Commerce.*': 'E-Commerce',
    r'.*Real[- ]?Estate.*': 'Real Estate',
    r'.*Hospitality.*': 'Hospitality',
    r'.*Logistics.*': 'Logistics',
    r'.*Travel.*Tech.*': 'Travel Tech',
    r'.*Health.*Platform.*': 'Health & Wellness',
    r'.*Healthcare.*': 'Health & Wellness',
    r'.*Fintech.*': 'FinTech',
    r'.*Hyperlocal.*': 'Hyperlocal Services',
    r'.*Agriculture.*': 'AgriTech',
    r'.*Clean.*Energy.*': 'CleanTech',
    r'.*Energy.*': 'Energy'
}, regex=True)

# Final cleanup
df[col] = df[col].str.strip().str.title()

# Number of unique values after cleaning
print("Number of unique values after cleaning: ",df['Industry Vertical'].nunique())
print('\n')

# Check cleaned unique values
print(df[col].unique())
# Out:
# Number of unique values after cleaning:  469
#
#
# ['E-Tech' 'Transportation' 'E-Commerce' 'Fintech' 'Fashion And Apparel'
#  'Logistics' 'Hospitality' 'Technology' 'Aerospace'
#  'B2B-Focused Foodtech Startup' 'Finance' 'Video' 'Gaming' 'Software'
#  'Health & Wellness' 'Edtech' 'B2B Marketing' 'Video Games' 'Saas'
#  'Last Mile Transportation' 'Customer Service' 'B2B'
#  'Advertising Marketing' 'Iot' 'Information Technology'
#  'Consumer Technology' 'Accounting' 'Retail' 'Customer Service Platform'
#  'Automotive' 'Consumer Goods' 'Food And Beverage' 'Compliance'
#  'Transport' 'Artificial Intelligence' 'Luxury Label'
#  'Waste Management Service' 'Deep-Tech' 'Agritech' 'Energy'
#  'Digital Media' 'Services' 'Automobile' 'Social Media' 'Nanotechnology'
#  'Services Platform' 'Travel Tech' 'Saas Ecommerce' 'Nbfc' 'Food'
#  'Food Tech' 'Automation' 'Investment' 'Real Estate' 'Consumer Internet'
#  'B2B Platform' 'Cleantech' 'Food & Beverages' 'Media' 'Publishing'
#  'Entertainment' 'Inspiration' 'Lifestyle' 'Food & Beverage'
#  'Consumer Portal' 'Others' 'Fmcg'
#  'Enterprise Marketing Automation Platform'
#  'Last Minute Hotel Booking App' 'Food Delivery'
#  'App Based Bus Pooling Services' 'On Demand Mobile App Developer'
#  'Car Maintenance & Management Mobile App'
#  'Custom Made Furniture E-Tailer' 'Qsr Chain'
#  'Smart Safety Wearable Devices' 'Cab Sharing Service Mobile App'
#  'Online School For Analytics Learning'
#  'Picture Creation & Social Mobile App' 'Nonbanking Finance Company'
#  'Online Freight Services Aggregator' 'Online Branded Furniture Etailer'
#  'Digital Analytics Platform' 'Internet Network Infrastructure Services'
#  'Mobile Point Of Sale Solutions'
#  'Peer-To-Peer Money Transfer & Recharge App'
#  'Test Automation Saas Platform' 'Online Rti Application Services'
#  'Wedding Venues & Vendors Marketplace' 'Modular Furnishings Marketplace'
#  'Cab Search Comparison & Booking Platform'
#  'Performance Optimization Platform For Athletes'
#  'Visual Search And Discovery Platform' 'Home Services Marketplace'
#  'Virtual Health Consultation App'
#  'Data Science & Ux Design Learning Platform'
#  'Electric Bike Manufacturers' 'International Hiring Platform'
#  'Grocery Delivery' 'Mobile Accessories Online Store'
#  'Medical Consultation & Doctor Appointment Booking Platform'
#  'Mobile Fitness App' 'Mobile Game Development & Design Platform'
#  'B2B Ecommerce Marketplace' 'B2B Merchandize Platform'
#  'Photographer Online Search & Booking Platform'
#  'Mobile Car Servicing Appointment App' 'New Curation Mobile App'
#  'Mobile Wallet' 'Bus Aggregation And Rental Mobile App'
#  'Alternate Mobile Monetization Platform'
#  'Quick Service Restaurant & Online Delivery' 'Budget Hotels Aggregator'
#  'Digital Intelligent Learning Platform'
#  'Online Counselling And Psychological Support Platform'
#  'Domestic Help Aggregation Platform' 'Home Stay & Room Rentals Platform'
#  'Online Grocery Platform' 'Online Content Platform For Women'
#  'Online Vehicle Spare Parts Etailer' 'Event Ticketing Platform'
#  'Premium Dining Lounges & Restaurants' 'Mobile Growth Hackingplatform'
#  'Skill Training Startup' 'Beauty And Wellness Marketplace'
#  'Marketplace App For Bangkok' 'On-Demand Maids Service Provider'
#  'Ecommerce Product Search Engine' 'Ready To Cook Packaged Foods'
#  'Branded Food Products Online Sales' 'Auto Insurance Online Platform'
#  'Cricket Management Mobile Game'
#  'Ecommerce Discount & Cashback Coupons Platform'
#  'Virtual Reality Headset Creator' 'Mobile-Only Tasks Marketplace'
#  'Numerical Computing & Data Science Platform'
#  'Designer Fashion Jewellery Marketplace'
#  'Online Products Discovery Platform'
#  'Kids Tool Kit For Innovation Platform' 'Mobile Learning Solutions'
#  'Car Aggregator & Retail Mobile App' 'Conversational Commerce Mobile App'
#  'Viral Content Web Platform' 'Mobile Services Marketplace'
#  'Smartwatch Maker' 'Online Jewellery Etailer'
#  'Sales & Productivity Software' 'Nightlife Discovery Mobile App'
#  'Indian Ethnic Crafts Etailer'
#  'Social Platform For Traders And Investors'
#  'Online Furniture Home Appliances Rental Platform'
#  'Health And Beauty Services Marketplace'
#  'Mobile App Based Loan Disbursement Platform'
#  'On Demand Laundry Services App' 'Education Content Provider'
#  'Fitness Tracking Management Solutions' 'Self Driven Rental Car Platform'
#  'Two-Wheeler Taxi Service' 'Character Merchandize Sales Platform'
#  'Ecommerce Delivery Locker Services' 'Movie-On-Demand Platform'
#  'Product Discovery & Recommendation Platform' 'Mobile Payments App'
#  'Beauty & Wellness Products E-Tailer'
#  'Fashion Jewelry And Accessories E-Tailer'
#  'Online Consumer Lending Platform' 'Premium Apparel Shopping Portal'
#  'Job Board' 'Sports Management & Physical Education Business'
#  'Qsr & Online Delivery Portal' 'Online Homeopathy Clinic'
#  'Gesture Based Mobile Development' 'Rental Accommodation Search Platform'
#  'Developer Portfolio Showcase Platform' 'End-To-End Lending Platform'
#  'Advertising & Marketing Community Networking Platform'
#  'Ride Sharing Platform' 'Cloud Based Collaboration Platform'
#  'Mobile Only Shopping Assistant' 'Mobile Messaging Assistant App'
#  'Personalized Wish List Creator App'
#  'Raw Meat & Ready To Eat Food Etailer'
#  'Structural & Civil Engg Service Automation' 'Payments Solution Platform'
#  'Travel Destination Discovery Platform' 'Last Mile Delivery Service'
#  'Micro-Brewery' 'Home Made Food Marketplace'
#  'Residential Rental Management Platform' 'Personal Diagnostic Mobile App'
#  'Hotel Aggregator & Booking Platform'
#  'Online Student & Campus Social Networking Platform'
#  'Professionals & Project Search Marketplace' 'Online Pharmacy'
#  'Online Payment Gateway'
#  'Location Based Nightlife Recommendation Platform'
#  'Asset Financing Platform'
#  'Virtual Reality Activity Based Learning Platform'
#  'Public Commute Helper App' 'Ridesharing Mobile App'
#  'Competitive Exam Learning Platform' 'Document Digitization Platform'
#  'Proximity Marketing & Mobile Advertising Platform'
#  'Autorickshaw Aggregator & Booking Platform'
#  'Personalized Styling Platform' 'Luxury Goods Shopping Platform'
#  'Cloud Software Solutions' 'Job Search Platform'
#  'Small Business Financing Nbfc' 'Online Movie Review Platform'
#  'Ecommerce Brandsxe2X80X99 Full Service Agency'
#  'Cloud-Based Hotel Booking Platform'
#  'Community Driven News/Views Platform' 'Study Material Marketplace'
#  'Restaurant Ratings & Reviews Platform'
#  'Dairy Based Product Manufacturer' 'Government Test Preparation Platform'
#  'Multilingual Test Preparation Platform' 'Industrial Tools Marketplace'
#  'Non Profit Organization To Alleviate Poverty'
#  'Gym & Fitness Studios Subscription Platform'
#  'Pre-Used Apparel Shopping Mobile App' 'Used Vehicles Marketplace'
#  'Mobile App Testing Platform' 'Hyperlocal Services'
#  'Early Cancer Detection Solutions' 'Cab Rental Mobile App'
#  'Online Insurance Distribution Platform'
#  'Mobile Marketing Automation Platform' 'Chain Of Tea Cafxc3Xa9Xe2X80X99S'
#  'Branded Budget Hotel Marketplace' 'Food Subscription Platform'
#  'Wedding Planning Platform' 'B2B Mobile Auction Marketplace'
#  'Private Label Fashion Etailer' 'Internet Of Things Platform'
#  'Diagnostic Labs Aggregator Platform' 'Home Medical Care Services'
#  'Real-Time Stock Data Platform' 'Coupons And Cashback Aggregator App'
#  'Financial Services Portal'
#  'Virtual Reality 3D Simulation And Stereoscopic Products'
#  'Online Interior Designing Platform' 'Private Label Apparel Sales'
#  'Cross-Device Retargeting Platform'
#  'Digital & Physical Publishing Platform'
#  'Data Driven Publishing Platform'
#  'Employee Onboarding & Orientation Platform'
#  'Solar Power Solutions Company' 'Online Meat Ordering Platform'
#  'Cab Booking App Platform' 'Mobile Advertising Platform'
#  'Fashion Discovery Platform' 'Big Data Management Platform'
#  'Budget Accommodation Platform' 'Digital Signal Processing Platform'
#  'Restaurant Discount App' 'Budget Hotel Accommodation Brand'
#  'User Engagment & Analytics Platform'
#  'Fund Raising Platform For Startups' 'Online Budget Hotel Chain'
#  'Hotel Booking App' 'Tech Platform For Property Brokers'
#  'App Security Testing Platform' 'Doctor Appointment Booking App'
#  'Crowd Funding Platform' 'Mobile Based Pos Solution'
#  'Fast Food Chain Franchisee' 'Loyalty Programs & Reward Points'
#  'Taxi Rental Platform' 'Mobile Social Network' 'Hyper-Local Ecommerce'
#  'Mobile Payment Software Platform'
#  'Automated Storage & Warehousing Solution'
#  'Home Design & Dxc3Xa9Cor Solutions' 'Quick Service Restaurant Chain'
#  'Subscription Based Online Grocery Platform'
#  'Engineering Services Company' 'Business And It Consulting'
#  'Credit Card Fraud Protection Solutions' 'Online & Mobile Grocery Store'
#  'Career Community For Women' 'Mutual Fund Investing Platform'
#  'Ecommerce Marketing Software Platform' 'Financial Inclusion Platform'
#  'Mobile Commerce For Farmers' 'Picture Based Social App'
#  'Exam Preparation Platform' 'Waste Management Solutions'
#  'On-Demand Delivery Service' 'Data Analytics Platform'
#  'Deep Learning Cloud Algorithms' 'Corporate Wellness App'
#  'Visual Blogging Platform' 'Food Customer Analytics Platform'
#  'Professional Service Appointment Booking Service'
#  'On-Demand App Based Professional Service Provider'
#  'Restaurant Reservation Platform' 'Cross-Channel Crm Platform'
#  'Professional Custom Creators Marketplace'
#  'On-Demand Washing & Dry-Cleaning' 'On-Demand Beauty Service'
#  'Online Food Community Platform' 'Beauty & Lifestyle Mobile Marketplace'
#  'Qsr Restaurant Chain' 'Online Coffee Delivery Platform'
#  'Language Localization Cloud Platform' 'Crm / Analytics Platform'
#  'It Infrastructure & Data Center Services' 'Online Financial Services'
#  'Used Car Marketplace' 'Language Learning App'
#  'Custom Merchandize Platform' 'Custom Furniture Marketplace'
#  'Ethnic Beverages Manufacturer' 'Budget Accommodation Aggregator'
#  'Music Streaming App' 'Big Data & Analytics Platform'
#  'Coupon Aggregator Platform' 'Celebrity Fashion Brand'
#  'Online Finance Lending Platform' 'Self-Driven Vehicle Rental'
#  'News Aggregator Mobile App' 'Online Jewellery Store'
#  'Fashion Info Aggregator App' 'Warranty Programs Service Administration'
#  'Pre-School Chain' 'Premium Loyalty Rewards Point Management'
#  'Contact Center Software Platform' 'Casual Dining Restaurant Chain'
#  'Online Comparison Engine' 'Physical Storage Warehouses'
#  'Tech Recruitment Platform' 'Bike Rental Platform'
#  'Budget Hotel Accommodation' 'Restaurant Customer Engagement Platform'
#  'F&B Sector Mobile Payment Platform' 'Industrial Supplies B2B Ecommerce'
#  'Payment Solutions Platform' 'Organic Food Ecommerce'
#  'Fine Dining Restaurant Chain' 'Luxury Rental Homes'
#  'Mobile Point Of Sale Payment Solution' 'Online Grocers'
#  'Clinical Genomics Provider' 'Travel Information Portal'
#  'Fitness Marketplace' 'Online & Mobile Classified Listings'
#  'Used Bikes Marketplace' 'Spa & Salon Management Software'
#  'Medical Tech Instruments' 'Innovative Water Solutions'
#  'Online Jewelry Store' 'Business Intelligence & Analytics'
#  'Used Vehicle Marketplace' 'Educational Board Games'
#  'Hasbro Toy Manufacturer' 'Healthy Food Manufacturer'
#  'Online Learning Platform' 'Healthy Food Online Community'
#  'Online Fashion Video Portal'
#  'Probiotic Technology Products Manufacturer'
#  'Architectural Design & Consulting' 'Big Data & Analytics Services'
#  'Online Car Rental Affiliates' 'Data Center Software Platform'
#  'Online City & Lifestyle Guide' 'Bespoke Merchandize Marketplace'
#  'Video Intelligence Platform' 'Auto Rickshaw Based Services'
#  'Off-Grid Solar Power' 'Private Label Lingerie Ecommerce'
#  'Online Food Ordering' 'Mobile Commerce Platform'
#  'Digital Marketing Services' 'Fashion Ecommerce Store'
#  'Mobile Compression Software' 'Peer To Peer Lending Platform'
#  'Home Furnishing Solutions' 'Online Coupon & Comparison Platform'
#  'Dental Clinic Chain' '3D Printer Manufacturer'
#  'It / Customer Engagement Consulting' 'Financial Services Platform'
#  'Social Network For Artists' 'Startup Funding Platform'
#  'Data Driven Recruitment Recommendation' 'Video Advertisement Platform'
#  'Mobile Chat Based Concierge Service'
#  'Online Budget Hotel Booking Service'
#  'Saas Product Intelligence Platform' 'App Analytics Platform'
#  'Micro Finance Platform' 'Credit Management Services'
#  'Marketing / Advertising Automation Platform' 'Flat Rental Mobile App'
#  'Wealth Management Platform' 'Fund Raising Platform'
#  'Workforce Management Software' 'Affordable Education'
#  'Career Development' 'Banking Analytics Platform'
#  'Online Product Comparison' 'Online Security Platform'
#  'Online Medical Diagnostic' 'Cloud Data Integration Platform'
#  'Mobile Laundry Cleaning Service' 'Lifestyle Ecommerce Portal'
#  'Online Fashion Aggregator' 'Online Job Skills Showcase'
#  'Offline Tea Chain' 'Business Messaging App' 'Health Mobile App'
#  'Online Ed-Tech Platform' 'Trucking Logistic Operations'
#  'B2C Messaging App' 'Customer Engagement Platform'
#  'Online Table Reservation' 'Parents Focused Web Content'
#  'On-Demand Service Marketplace' 'On-Demand Business Messaging'
#  'Online Home Dxc3Xa9Cor' 'Api Workflow Platform'
#  'Affordable Hotel Booking Online' 'Self-Driven Car Rental'
#  'Electric Scooter Manufacturer' 'Web Content Publishing'
#  'Location Based App' 'Video Streaming' 'Price Comparison'
#  'Online Classifieds' 'Travel Entertainment' 'Digital / Mobile Wallet'
#  'Cab Aggregator' 'Device Repair Svcs' 'Premium Beverages'
#  'Online Furnishingecommerce' 'Interactive How-To Guides'
#  'Restaurant Reviews' 'Online Grocer' 'Online Hotel Booking'
#  'Online Kitchen Furniture' 'Hyper-Local Online Services'
#  'Hyper-Local Online/Mobile Grocery' 'Online Policy Aggregator'
#  'Ondemandmobile Handyman Services' 'Mobile App Development'
#  'Material Collection & Recycling' 'Online Pharmacy & Drug Db'
#  'Online / Mobile Customer Support' 'Online Classifieds & Listings'
#  'Fashion Ecommerce' 'Private Coaching Centers'
#  'Online Certification Courses' 'Ethnic Product Ecommerce'
#  'Last Minute Travel Deals Mobile Marketplace'
#  'Usiness Expense Management' 'Online Insurance Aggregator'
#  'Restaurant Management Platform' 'Interactive Educational Games'
#  'Grey Collar Job Board' 'Robotic Program Learning'
#  'Tele-Shopping / Ecommerce' 'Used Gadgets Buy / Refurbishing'
#  'Cloud Enterprise Software' 'Startup Analytics Platform'
#  'Financial Markets Software' 'Hiring Analytics Platform' 'Unknown']

# %%
# Clean and standardize 'Industry Vertical' column
col = 'Investors Name'

# Convert to string and clean all encoded/backslash artifacts
df[col] = (
    df[col]
    .astype(str)
    .str.replace(r'\\+', '', regex=True)          # remove any number of backslashes
    .str.replace(r'xc2|xa0|n', '', regex=True)    # remove leftover encoded characters
    .str.replace(r'\s+', ' ', regex=True)         # normalize multiple spaces
    .str.strip()
)

# %%
# Number of unique values before cleaning
df['Investment Type'].nunique()
# Out:
# 51

# %%
# Column name
col = 'Investment Type'

# Convert to string, remove artifacts, and strip spaces
df[col] = df[col].astype(str).str.replace(r'\\n', '', regex=True).str.strip()

# Standardize common investment types
df[col] = df[col].replace({
    # Pre-Series A variants
    'Pre-series A': 'Pre-Series A',
    'pre-series A': 'Pre-Series A',

    # Seed funding variants
    'Seed': 'Seed Funding',
    'Seed Round': 'Seed Funding',
    'Seed Funding Round': 'Seed Funding',
    'Seed/Angel Funding': 'Seed/Angel Funding',
    'Angel / Seed Funding': 'Seed/Angel Funding',
    'Seed\\Funding': 'Seed Funding',
    'Seed\\\\\\Funding':'Seed Funding',

    # Private equity
    'Private Equity': 'Private Equity',
    'Private Equity Round': 'Private Equity',
    'Private\\Equity': 'Private Equity',
    'PrivateEquity': 'Private Equity',
    'Private Funding': 'Private Equity',
    'Private': 'Private Equity',
    'Private\\\\\\Equity':'Private Equity',


    # Debt
    'Debt': 'Debt Funding',
    'Debt Funding': 'Debt Funding',
    'Debt And Preference Capital': 'Debt Funding',
    'Structured Debt': 'Debt Funding',
    'Term Loan': 'Debt Funding',

    # Equity
    'Equity': 'Equity Funding',
    'Equity Funding': 'Equity Funding',

    # Series rounds
    'Series A': 'Series A',
    'Series B': 'Series B',
    'Series B (Extension)': 'Series B',
    'Series C': 'Series C',
    'Series D': 'Series D',
    'Series E': 'Series E',
    'Series F': 'Series F',
    'Series G': 'Series G',
    'Series H': 'Series H',
    'Series J': 'Series J',

    # Angel
    'Angel': 'Angel',
    'Angel Round': 'Angel',

    # Other types
    'Maiden Round': 'Maiden Round',
    'Funding Round': 'Funding Round',
    'Single Venture': 'Single Venture',
    'Corporate Round': 'Corporate Round',
    'Venture Round': 'Venture Round',
    'Venture - Series Unknown': 'Venture - Series Unknown',
    'Inhouse Funding': 'Inhouse Funding',
    'Mezzanine': 'Mezzanine',
    'Crowd Funding': 'Crowd Funding',
    'Unknown': 'Unknown'
})

# Title case for consistency
df[col] = df[col].str.title()

# Number of unique values after cleaning
print("Number of unique values after cleaning: ",df['Investment Type'].nunique())
print('\n')

# Check cleaned unique values
print(df[col].unique())
# Out:
# Number of unique values after cleaning:  31
#
#
# ['Private Equity' 'Series C' 'Series B' 'Pre-Series A' 'Seed Funding'
#  'Series A' 'Series D' 'Series F' 'Series E' 'Debt Funding' 'Series G'
#  'Series H' 'Unknown' 'Funding Round' 'Maiden Round' 'Single Venture'
#  'Corporate Round' 'Venture Round' 'Angel' 'Series J'
#  'Venture - Series Unknown' 'Inhouse Funding' 'Seed/ Angel Funding'
#  'Equity Funding' 'Debt-Funding' 'Mezzanine' 'Equity Based Funding'
#  'Seed / Angel Funding' 'Seed/Angel Funding' 'Seed / Angle Funding'
#  'Crowd Funding']

# %%
# Renumber serial number after cleaning
# Reset index and start Sr No from 1
df.reset_index(drop=True, inplace=True)
df['Sr No'] = df.index + 1

# %%
df.tail()
# Out:
#       Sr No       Date      Startup Name Industry Vertical SubVertical  \
# 2072   2073 2015-01-28     Grabhouse.com           Unknown     Unknown
# 2073   2074 2015-01-29        Printvenue           Unknown     Unknown
# 2074   2075 2015-01-29          Graphene           Unknown     Unknown
# 2075   2076 2015-01-30    Mad Street Den           Unknown     Unknown
# 2076   2077 2015-01-31  couponmachine.in           Unknown     Unknown
#
#      City Location                    Investors Name Investment Type  \
# 2072       Unknown  Kalaari Capital, Sequoia Capital  Private Equity
# 2073       Unknown         Asia Pacific Iteret Group  Private Equity
# 2074       Unknown                     KARSEMVEN Fud  Private Equity
# 2075       Unknown       Exfiity Fud, GrowX Vetures.  Private Equity
# 2076       Unknown   UK based Group of Agel Ivestors    Seed Funding
#
#       Amount in USD(K)  Amount in INR(K)              Remarks City Tier
# 2072            2500.0          220000.0             Series A     Other
# 2073            4500.0          396000.0            No Remark     Other
# 2074             825.0           72600.0  Govt backed VC Fund     Other
# 2075            1500.0          132000.0            No Remark     Other
# 2076             140.0           12320.0            No Remark     Other

# %%
# Rechecking for any missing values
df.isna().sum()
# Out:
# Sr No                0
# Date                 0
# Startup Name         0
# Industry Vertical    0
# SubVertical          0
# City Location        0
# Investors Name       0
# Investment Type      0
# Amount in USD(K)     0
# Amount in INR(K)     0
# Remarks              0
# City Tier            0
# dtype: int64

# %%
# Saving Cleaned dataset for next process
cleaned_df = df.to_csv('startup_funding_clean.csv',index = False)

# %%
# Summary statistics after cleaning
df.describe()
# Out:
#              Sr No                           Date  Amount in USD(K)  \
# count  2077.000000                           2077      2.077000e+03
# mean   1039.000000  2016-10-22 11:57:34.405392128      2.233217e+04
# min       1.000000            2015-01-02 00:00:00      2.000000e-02
# 25%     520.000000            2015-10-21 00:00:00      4.700000e+02
# 50%    1039.000000            2016-08-19 00:00:00      1.750000e+03
# 75%    1558.000000            2017-09-05 00:00:00      8.200000e+03
# max    2077.000000            2020-01-13 00:00:00      3.900000e+06
# std     599.722575                            NaN      1.494657e+05
#
#        Amount in INR(K)
# count      2.077000e+03
# mean       1.965231e+06
# min        1.760000e+00
# 25%        4.136000e+04
# 50%        1.540000e+05
# 75%        7.216000e+05
# max        3.432000e+08
# std        1.315298e+07

# %%
# Sample of the cleaned dataset
df.head()
# Out:
#    Sr No       Date                  Startup Name    Industry Vertical  \
# 0      1 2020-01-09                   BYJU\u2019S               E-Tech
# 1      2 2020-01-13                        Shuttl       Transportation
# 2      3 2020-01-09                     Mamaearth           E-Commerce
# 3      4 2020-01-02  https://www.wealthbucket.in/              Fintech
# 4      5 2020-01-02                        Fashor  Fashion And Apparel
#
#                              SubVertical City Location  \
# 0                             E-learning     Bengaluru
# 1              App based shuttle service       Gurgaon
# 2  Retailer of baby and toddler products     Bengaluru
# 3                      Online Investment     New Delhi
# 4            Embroiled Clothes For Women        Mumbai
#
#             Investors Name Investment Type  Amount in USD(K)  \
# 0    Tiger Global Maagemet  Private Equity         200000.00
# 1  Susquehaa Growth Equity        Series C           8048.39
# 2     Sequoia Capital Idia        Series B          18358.86
# 3            Viod Khatumal    Pre-Series A           3000.00
# 4    Sprout Veture Parters    Seed Funding           1800.00
#
#    Amount in INR(K)    Remarks     City Tier
# 0       17600000.00  No Remark  Tier 1 India
# 1         708258.32  No Remark  Tier 1 India
# 2        1615579.68  No Remark  Tier 1 India
# 3         264000.00  No Remark  Tier 1 India
# 4         158400.00  No Remark  Tier 1 India

# %%
# Basic Statistics
min_usd = df['Amount in USD(K)'].min()
max_usd = df['Amount in USD(K)'].max()
avg_usd = df['Amount in USD(K)'].mean()
print("Minimum Amount in USD(K) : ",min_usd)
print("Maximum Amount in USD(K) : ",max_usd)
print("Average Amount in USD(K) : ",avg_usd)
# Out:
# Minimum Amount in USD(K) :  0.02
# Maximum Amount in USD(K) :  3900000.0
# Average Amount in USD(K) :  22332.168964853154
